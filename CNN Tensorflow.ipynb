# %%
import tensorflow as tf
from keras.layers import Dense,Activation,Dropout
from keras.optimizers import Adam
from keras.models import Sequential

# %%
mnist=tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train,x_test = x_train/255.0,x_test/255.0

# %%
model=tf.keras.models.Sequential([
tf.keras.layers.Flatten(input_shape=(28,28)),
tf.keras.layers.Dense(512,activation='relu'),
tf.keras.layers.Dropout(0,2),
tf.keras.layers.Dense(10,activation='softmax')
])

# %%
model.compile(optimizer='SGD',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
tf_callbacks=tf.keras.callbacks.TensorBoard(log_dir="log/fit",histogram_freq=1)

# %%
history=model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=10,callbacks=tf_callbacks)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 63s 31ms/step - loss: 0.6016 - accuracy: 0.8531 - val_loss: 0.3400 - val_accuracy: 0.9090
# Epoch 2/10
# 1875/1875 [==============================] - 54s 29ms/step - loss: 0.3228 - accuracy: 0.9104 - val_loss: 0.2793 - val_accuracy: 0.9226
# Epoch 3/10
# 1875/1875 [==============================] - 54s 29ms/step - loss: 0.2754 - accuracy: 0.9228 - val_loss: 0.2514 - val_accuracy: 0.9268
# Epoch 4/10
# 1875/1875 [==============================] - 55s 29ms/step - loss: 0.2453 - accuracy: 0.9322 - val_loss: 0.2241 - val_accuracy: 0.9364
# Epoch 5/10
# 1875/1875 [==============================] - 55s 29ms/step - loss: 0.2219 - accuracy: 0.9385 - val_loss: 0.2068 - val_accuracy: 0.9400
# Epoch 6/10
# 1875/1875 [==============================] - 57s 31ms/step - loss: 0.2029 - accuracy: 0.9432 - val_loss: 0.1923 - val_accuracy: 0.9452
# Epoch 7/10
# 1875/1875 [==============================] - 54s 29ms/step - loss: 0.1871 - accuracy: 0.9479 - val_loss: 0.1787 - val_accuracy: 0.9492
# Epoch 8/10
# 1875/1875 [==============================] - 55s 29ms/step - loss: 0.1738 - accuracy: 0.9517 - val_loss: 0.1666 - val_accuracy: 0.9530
# Epoch 9/10
# 1875/1875 [==============================] - 55s 29ms/step - loss: 0.1622 - accuracy: 0.9550 - val_loss: 0.1580 - val_accuracy: 0.9542
# Epoch 10/10
# 1875/1875 [==============================] - 57s 30ms/step - loss: 0.1520 - accuracy: 0.9578 - val_loss: 0.1508 - val_accuracy: 0.9568

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
tensorboard --logdir log/fit
# Out:
# Reusing TensorBoard on port 6006 (pid 6028), started 16 days, 1:12:32 ago. (Use '!kill 6028' to kill it.)
#       <iframe id="tensorboard-frame-3e3adc970e4a15bf" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-3e3adc970e4a15bf");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train','test'],loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train','test'],loc='upper left')
plt.show()

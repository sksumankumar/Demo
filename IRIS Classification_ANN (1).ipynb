# %%
"""
    A simple neural network written in Keras (TensorFlow backend) to classify the IRIS data
"""

import numpy as np

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
iris_data = load_iris() # load the iris dataset

x = iris_data.data
y_ = iris_data.target.reshape(-1, 1) # Convert data to a single column

# %%
# One Hot encode the class labels
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y_)

# %%
# Split the data for training and testing
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# %%
# Build the model
model = Sequential()
model.add(Dense(10, input_shape=(4,), activation='relu', name='input'))
model.add(Dense(10, activation='relu', name='fc2'))
model.add(Dense(3, activation='softmax', name='output'))

# %%
# Adam optimizer with learning rate of 0.001
optimizer = Adam(lr=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('Neural Network Model Summary: ')
print(model.summary())
# Out:
# Neural Network Model Summary:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (Dense)               (None, 10)                50
#
#  fc2 (Dense)                 (None, 10)                110
#
#  output (Dense)              (None, 3)                 33
#
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Users\YASH\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=200)
# Out:
# Epoch 1/200
# 24/24 - 1s - loss: 1.2600 - accuracy: 0.3417 - 532ms/epoch - 22ms/step
# Epoch 2/200
# 24/24 - 0s - loss: 1.1552 - accuracy: 0.3417 - 47ms/epoch - 2ms/step
# Epoch 3/200
# 24/24 - 0s - loss: 1.0747 - accuracy: 0.3417 - 43ms/epoch - 2ms/step
# Epoch 4/200
# 24/24 - 0s - loss: 1.0006 - accuracy: 0.3417 - 34ms/epoch - 1ms/step
# Epoch 5/200
# 24/24 - 0s - loss: 0.8958 - accuracy: 0.4417 - 22ms/epoch - 912us/step
# Epoch 6/200
# 24/24 - 0s - loss: 0.7792 - accuracy: 0.8000 - 44ms/epoch - 2ms/step
# Epoch 7/200
# 24/24 - 0s - loss: 0.6940 - accuracy: 0.7833 - 22ms/epoch - 935us/step
# Epoch 8/200
# 24/24 - 0s - loss: 0.6294 - accuracy: 0.8167 - 33ms/epoch - 1ms/step
# Epoch 9/200
# 24/24 - 0s - loss: 0.5840 - accuracy: 0.8917 - 33ms/epoch - 1ms/step
# Epoch 10/200
# 24/24 - 0s - loss: 0.5456 - accuracy: 0.9250 - 32ms/epoch - 1ms/step
# Epoch 11/200
# 24/24 - 0s - loss: 0.5061 - accuracy: 0.8667 - 32ms/epoch - 1ms/step
# Epoch 12/200
# 24/24 - 0s - loss: 0.4716 - accuracy: 0.9167 - 32ms/epoch - 1ms/step
# Epoch 13/200
# 24/24 - 0s - loss: 0.4463 - accuracy: 0.9667 - 27ms/epoch - 1ms/step
# Epoch 14/200
# 24/24 - 0s - loss: 0.4247 - accuracy: 0.9417 - 35ms/epoch - 1ms/step
# Epoch 15/200
# 24/24 - 0s - loss: 0.4038 - accuracy: 0.9583 - 33ms/epoch - 1ms/step
# Epoch 16/200
# 24/24 - 0s - loss: 0.3850 - accuracy: 0.9583 - 33ms/epoch - 1ms/step
# Epoch 17/200
# 24/24 - 0s - loss: 0.3695 - accuracy: 0.9583 - 34ms/epoch - 1ms/step
# Epoch 18/200
# 24/24 - 0s - loss: 0.3578 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 19/200
# 24/24 - 0s - loss: 0.3473 - accuracy: 0.9333 - 35ms/epoch - 1ms/step
# Epoch 20/200
# 24/24 - 0s - loss: 0.3209 - accuracy: 0.9750 - 22ms/epoch - 905us/step
# Epoch 21/200
# 24/24 - 0s - loss: 0.3021 - accuracy: 0.9833 - 33ms/epoch - 1ms/step
# Epoch 22/200
# 24/24 - 0s - loss: 0.2882 - accuracy: 0.9667 - 33ms/epoch - 1ms/step
# Epoch 23/200
# 24/24 - 0s - loss: 0.2722 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 24/200
# 24/24 - 0s - loss: 0.2576 - accuracy: 0.9750 - 34ms/epoch - 1ms/step
# Epoch 25/200
# 24/24 - 0s - loss: 0.2488 - accuracy: 0.9667 - 33ms/epoch - 1ms/step
# Epoch 26/200
# 24/24 - 0s - loss: 0.2311 - accuracy: 0.9750 - 24ms/epoch - 1ms/step
# Epoch 27/200
# 24/24 - 0s - loss: 0.2214 - accuracy: 0.9833 - 48ms/epoch - 2ms/step
# Epoch 28/200
# 24/24 - 0s - loss: 0.2116 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 29/200
# 24/24 - 0s - loss: 0.2103 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 30/200
# 24/24 - 0s - loss: 0.1923 - accuracy: 0.9833 - 43ms/epoch - 2ms/step
# Epoch 31/200
# 24/24 - 0s - loss: 0.1851 - accuracy: 0.9833 - 25ms/epoch - 1ms/step
# Epoch 32/200
# 24/24 - 0s - loss: 0.1763 - accuracy: 0.9833 - 45ms/epoch - 2ms/step
# Epoch 33/200
# 24/24 - 0s - loss: 0.1735 - accuracy: 0.9833 - 20ms/epoch - 816us/step
# Epoch 34/200
# 24/24 - 0s - loss: 0.1664 - accuracy: 0.9833 - 34ms/epoch - 1ms/step
# Epoch 35/200
# 24/24 - 0s - loss: 0.1645 - accuracy: 0.9750 - 37ms/epoch - 2ms/step
# Epoch 36/200
# 24/24 - 0s - loss: 0.1596 - accuracy: 0.9583 - 35ms/epoch - 1ms/step
# Epoch 37/200
# 24/24 - 0s - loss: 0.1515 - accuracy: 0.9833 - 22ms/epoch - 911us/step
# Epoch 38/200
# 24/24 - 0s - loss: 0.1476 - accuracy: 0.9750 - 21ms/epoch - 856us/step
# Epoch 39/200
# 24/24 - 0s - loss: 0.1461 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 40/200
# 24/24 - 0s - loss: 0.1396 - accuracy: 0.9750 - 43ms/epoch - 2ms/step
# Epoch 41/200
# 24/24 - 0s - loss: 0.1350 - accuracy: 0.9833 - 35ms/epoch - 1ms/step
# Epoch 42/200
# 24/24 - 0s - loss: 0.1373 - accuracy: 0.9500 - 34ms/epoch - 1ms/step
# Epoch 43/200
# 24/24 - 0s - loss: 0.1341 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 44/200
# 24/24 - 0s - loss: 0.1256 - accuracy: 0.9833 - 33ms/epoch - 1ms/step
# Epoch 45/200
# 24/24 - 0s - loss: 0.1301 - accuracy: 0.9667 - 34ms/epoch - 1ms/step
# Epoch 46/200
# 24/24 - 0s - loss: 0.1297 - accuracy: 0.9750 - 26ms/epoch - 1ms/step
# Epoch 47/200
# 24/24 - 0s - loss: 0.1329 - accuracy: 0.9417 - 33ms/epoch - 1ms/step
# Epoch 48/200
# 24/24 - 0s - loss: 0.1163 - accuracy: 0.9750 - 18ms/epoch - 757us/step
# Epoch 49/200
# 24/24 - 0s - loss: 0.1168 - accuracy: 0.9833 - 35ms/epoch - 1ms/step
# Epoch 50/200
# 24/24 - 0s - loss: 0.1164 - accuracy: 0.9833 - 31ms/epoch - 1ms/step
# Epoch 51/200
# 24/24 - 0s - loss: 0.1113 - accuracy: 0.9750 - 34ms/epoch - 1ms/step
# Epoch 52/200
# 24/24 - 0s - loss: 0.1095 - accuracy: 0.9750 - 32ms/epoch - 1ms/step
# Epoch 53/200
# 24/24 - 0s - loss: 0.1123 - accuracy: 0.9833 - 33ms/epoch - 1ms/step
# Epoch 54/200
# 24/24 - 0s - loss: 0.1084 - accuracy: 0.9750 - 47ms/epoch - 2ms/step
# Epoch 55/200
# 24/24 - 0s - loss: 0.1074 - accuracy: 0.9750 - 30ms/epoch - 1ms/step
# Epoch 56/200
# 24/24 - 0s - loss: 0.1033 - accuracy: 0.9833 - 29ms/epoch - 1ms/step
# Epoch 57/200
# 24/24 - 0s - loss: 0.1045 - accuracy: 0.9833 - 30ms/epoch - 1ms/step
# Epoch 58/200
# 24/24 - 0s - loss: 0.1042 - accuracy: 0.9833 - 35ms/epoch - 1ms/step
# Epoch 59/200
# 24/24 - 0s - loss: 0.1000 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 60/200
# 24/24 - 0s - loss: 0.0990 - accuracy: 0.9833 - 33ms/epoch - 1ms/step
# Epoch 61/200
# 24/24 - 0s - loss: 0.1011 - accuracy: 0.9667 - 34ms/epoch - 1ms/step
# Epoch 62/200
# 24/24 - 0s - loss: 0.1035 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 63/200
# 24/24 - 0s - loss: 0.1020 - accuracy: 0.9750 - 30ms/epoch - 1ms/step
# Epoch 64/200
# 24/24 - 0s - loss: 0.0972 - accuracy: 0.9750 - 29ms/epoch - 1ms/step
# Epoch 65/200
# 24/24 - 0s - loss: 0.0952 - accuracy: 0.9750 - 30ms/epoch - 1ms/step
# Epoch 66/200
# 24/24 - 0s - loss: 0.0990 - accuracy: 0.9750 - 28ms/epoch - 1ms/step
# Epoch 67/200
# 24/24 - 0s - loss: 0.0949 - accuracy: 0.9750 - 30ms/epoch - 1ms/step
# Epoch 68/200
# 24/24 - 0s - loss: 0.0943 - accuracy: 0.9750 - 29ms/epoch - 1ms/step
# Epoch 69/200
# 24/24 - 0s - loss: 0.0927 - accuracy: 0.9833 - 29ms/epoch - 1ms/step
# Epoch 70/200
# 24/24 - 0s - loss: 0.0961 - accuracy: 0.9750 - 19ms/epoch - 786us/step
# Epoch 71/200
# 24/24 - 0s - loss: 0.1083 - accuracy: 0.9500 - 21ms/epoch - 868us/step
# Epoch 72/200
# 24/24 - 0s - loss: 0.1023 - accuracy: 0.9750 - 22ms/epoch - 899us/step
# Epoch 73/200
# 24/24 - 0s - loss: 0.0883 - accuracy: 0.9750 - 45ms/epoch - 2ms/step
# Epoch 74/200
# 24/24 - 0s - loss: 0.0954 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 75/200
# 24/24 - 0s - loss: 0.0869 - accuracy: 0.9750 - 19ms/epoch - 804us/step
# Epoch 76/200
# 24/24 - 0s - loss: 0.0894 - accuracy: 0.9833 - 20ms/epoch - 847us/step
# Epoch 77/200
# 24/24 - 0s - loss: 0.0902 - accuracy: 0.9833 - 34ms/epoch - 1ms/step
# Epoch 78/200
# 24/24 - 0s - loss: 0.0862 - accuracy: 0.9750 - 22ms/epoch - 921us/step
# Epoch 79/200
# 24/24 - 0s - loss: 0.0835 - accuracy: 0.9833 - 44ms/epoch - 2ms/step
# Epoch 80/200
# 24/24 - 0s - loss: 0.0878 - accuracy: 0.9750 - 20ms/epoch - 826us/step
# Epoch 81/200
# 24/24 - 0s - loss: 0.0950 - accuracy: 0.9667 - 20ms/epoch - 843us/step
# Epoch 82/200
# 24/24 - 0s - loss: 0.0878 - accuracy: 0.9750 - 34ms/epoch - 1ms/step
# Epoch 83/200
# 24/24 - 0s - loss: 0.0826 - accuracy: 0.9833 - 33ms/epoch - 1ms/step
# Epoch 84/200
# 24/24 - 0s - loss: 0.0829 - accuracy: 0.9750 - 34ms/epoch - 1ms/step
# Epoch 85/200
# 24/24 - 0s - loss: 0.0821 - accuracy: 0.9750 - 32ms/epoch - 1ms/step
# Epoch 86/200
# 24/24 - 0s - loss: 0.0816 - accuracy: 0.9833 - 33ms/epoch - 1ms/step
# Epoch 87/200
# 24/24 - 0s - loss: 0.0825 - accuracy: 0.9750 - 35ms/epoch - 1ms/step
# Epoch 88/200
# 24/24 - 0s - loss: 0.0912 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 89/200
# 24/24 - 0s - loss: 0.0842 - accuracy: 0.9750 - 35ms/epoch - 1ms/step
# Epoch 90/200
# 24/24 - 0s - loss: 0.0878 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 91/200
# 24/24 - 0s - loss: 0.0906 - accuracy: 0.9667 - 30ms/epoch - 1ms/step
# Epoch 92/200
# 24/24 - 0s - loss: 0.0845 - accuracy: 0.9750 - 29ms/epoch - 1ms/step
# Epoch 93/200
# 24/24 - 0s - loss: 0.0794 - accuracy: 0.9833 - 38ms/epoch - 2ms/step
# Epoch 94/200
# 24/24 - 0s - loss: 0.0802 - accuracy: 0.9833 - 26ms/epoch - 1ms/step
# Epoch 95/200
# 24/24 - 0s - loss: 0.0801 - accuracy: 0.9833 - 23ms/epoch - 963us/step
# Epoch 96/200
# 24/24 - 0s - loss: 0.0781 - accuracy: 0.9833 - 33ms/epoch - 1ms/step
# Epoch 97/200
# 24/24 - 0s - loss: 0.0783 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 98/200
# 24/24 - 0s - loss: 0.0798 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 99/200
# 24/24 - 0s - loss: 0.0814 - accuracy: 0.9667 - 33ms/epoch - 1ms/step
# Epoch 100/200
# 24/24 - 0s - loss: 0.0787 - accuracy: 0.9833 - 32ms/epoch - 1ms/step
# Epoch 101/200
# 24/24 - 0s - loss: 0.0770 - accuracy: 0.9833 - 31ms/epoch - 1ms/step
# Epoch 102/200
# 24/24 - 0s - loss: 0.0854 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 103/200
# 24/24 - 0s - loss: 0.0769 - accuracy: 0.9750 - 30ms/epoch - 1ms/step
# Epoch 104/200
# 24/24 - 0s - loss: 0.0754 - accuracy: 0.9833 - 29ms/epoch - 1ms/step
# Epoch 105/200
# 24/24 - 0s - loss: 0.0759 - accuracy: 0.9750 - 30ms/epoch - 1ms/step
# Epoch 106/200
# 24/24 - 0s - loss: 0.0783 - accuracy: 0.9833 - 29ms/epoch - 1ms/step
# Epoch 107/200
# 24/24 - 0s - loss: 0.0760 - accuracy: 0.9833 - 18ms/epoch - 730us/step
# Epoch 108/200
# 24/24 - 0s - loss: 0.0820 - accuracy: 0.9750 - 34ms/epoch - 1ms/step
# Epoch 109/200
# 24/24 - 0s - loss: 0.0782 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 110/200
# 24/24 - 0s - loss: 0.0758 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 111/200
# 24/24 - 0s - loss: 0.0754 - accuracy: 0.9833 - 33ms/epoch - 1ms/step
# Epoch 112/200
# 24/24 - 0s - loss: 0.0748 - accuracy: 0.9833 - 38ms/epoch - 2ms/step
# Epoch 113/200
# 24/24 - 0s - loss: 0.0754 - accuracy: 0.9833 - 33ms/epoch - 1ms/step
# Epoch 114/200
# 24/24 - 0s - loss: 0.0799 - accuracy: 0.9750 - 26ms/epoch - 1ms/step
# Epoch 115/200
# 24/24 - 0s - loss: 0.0785 - accuracy: 0.9750 - 38ms/epoch - 2ms/step
# Epoch 116/200
# 24/24 - 0s - loss: 0.0754 - accuracy: 0.9750 - 28ms/epoch - 1ms/step
# Epoch 117/200
# 24/24 - 0s - loss: 0.0856 - accuracy: 0.9667 - 28ms/epoch - 1ms/step
# Epoch 118/200
# 24/24 - 0s - loss: 0.0747 - accuracy: 0.9833 - 17ms/epoch - 715us/step
# Epoch 119/200
# 24/24 - 0s - loss: 0.0735 - accuracy: 0.9833 - 33ms/epoch - 1ms/step
# Epoch 120/200
# 24/24 - 0s - loss: 0.0728 - accuracy: 0.9833 - 32ms/epoch - 1ms/step
# Epoch 121/200
# 24/24 - 0s - loss: 0.0817 - accuracy: 0.9750 - 34ms/epoch - 1ms/step
# Epoch 122/200
# 24/24 - 0s - loss: 0.0951 - accuracy: 0.9667 - 18ms/epoch - 770us/step
# Epoch 123/200
# 24/24 - 0s - loss: 0.0862 - accuracy: 0.9500 - 34ms/epoch - 1ms/step
# Epoch 124/200
# 24/24 - 0s - loss: 0.0821 - accuracy: 0.9667 - 36ms/epoch - 2ms/step
# Epoch 125/200
# 24/24 - 0s - loss: 0.0738 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 126/200
# 24/24 - 0s - loss: 0.0776 - accuracy: 0.9750 - 32ms/epoch - 1ms/step
# Epoch 127/200
# 24/24 - 0s - loss: 0.0770 - accuracy: 0.9750 - 30ms/epoch - 1ms/step
# Epoch 128/200
# 24/24 - 0s - loss: 0.0736 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 129/200
# 24/24 - 0s - loss: 0.0762 - accuracy: 0.9750 - 37ms/epoch - 2ms/step
# Epoch 130/200
# 24/24 - 0s - loss: 0.0753 - accuracy: 0.9750 - 30ms/epoch - 1ms/step
# Epoch 131/200
# 24/24 - 0s - loss: 0.0837 - accuracy: 0.9667 - 32ms/epoch - 1ms/step
# Epoch 132/200
# 24/24 - 0s - loss: 0.0766 - accuracy: 0.9750 - 30ms/epoch - 1ms/step
# Epoch 133/200
# 24/24 - 0s - loss: 0.0735 - accuracy: 0.9667 - 31ms/epoch - 1ms/step
# Epoch 134/200
# 24/24 - 0s - loss: 0.0742 - accuracy: 0.9833 - 26ms/epoch - 1ms/step
# Epoch 135/200
# 24/24 - 0s - loss: 0.0695 - accuracy: 0.9833 - 39ms/epoch - 2ms/step
# Epoch 136/200
# 24/24 - 0s - loss: 0.0744 - accuracy: 0.9833 - 30ms/epoch - 1ms/step
# Epoch 137/200
# 24/24 - 0s - loss: 0.0705 - accuracy: 0.9833 - 31ms/epoch - 1ms/step
# Epoch 138/200
# 24/24 - 0s - loss: 0.0795 - accuracy: 0.9750 - 30ms/epoch - 1ms/step
# Epoch 139/200
# 24/24 - 0s - loss: 0.0694 - accuracy: 0.9833 - 29ms/epoch - 1ms/step
# Epoch 140/200
# 24/24 - 0s - loss: 0.0861 - accuracy: 0.9750 - 29ms/epoch - 1ms/step
# Epoch 141/200
# 24/24 - 0s - loss: 0.0697 - accuracy: 0.9833 - 30ms/epoch - 1ms/step
# Epoch 142/200
# 24/24 - 0s - loss: 0.0729 - accuracy: 0.9750 - 18ms/epoch - 744us/step
# Epoch 143/200
# 24/24 - 0s - loss: 0.0783 - accuracy: 0.9667 - 20ms/epoch - 846us/step
# Epoch 144/200
# 24/24 - 0s - loss: 0.0707 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 145/200
# 24/24 - 0s - loss: 0.0716 - accuracy: 0.9833 - 56ms/epoch - 2ms/step
# Epoch 146/200
# 24/24 - 0s - loss: 0.0758 - accuracy: 0.9750 - 29ms/epoch - 1ms/step
# Epoch 147/200
# 24/24 - 0s - loss: 0.0719 - accuracy: 0.9833 - 28ms/epoch - 1ms/step
# Epoch 148/200
# 24/24 - 0s - loss: 0.0851 - accuracy: 0.9750 - 29ms/epoch - 1ms/step
# Epoch 149/200
# 24/24 - 0s - loss: 0.0691 - accuracy: 0.9833 - 32ms/epoch - 1ms/step
# Epoch 150/200
# 24/24 - 0s - loss: 0.0693 - accuracy: 0.9833 - 30ms/epoch - 1ms/step
# Epoch 151/200
# 24/24 - 0s - loss: 0.0681 - accuracy: 0.9750 - 32ms/epoch - 1ms/step
# Epoch 152/200
# 24/24 - 0s - loss: 0.0733 - accuracy: 0.9833 - 32ms/epoch - 1ms/step
# Epoch 153/200
# 24/24 - 0s - loss: 0.0674 - accuracy: 0.9750 - 30ms/epoch - 1ms/step
# Epoch 154/200
# 24/24 - 0s - loss: 0.0714 - accuracy: 0.9833 - 31ms/epoch - 1ms/step
# Epoch 155/200
# 24/24 - 0s - loss: 0.0744 - accuracy: 0.9833 - 32ms/epoch - 1ms/step
# Epoch 156/200
# 24/24 - 0s - loss: 0.0720 - accuracy: 0.9833 - 32ms/epoch - 1ms/step
# Epoch 157/200
# 24/24 - 0s - loss: 0.0739 - accuracy: 0.9750 - 30ms/epoch - 1ms/step
# Epoch 158/200
# 24/24 - 0s - loss: 0.0694 - accuracy: 0.9750 - 32ms/epoch - 1ms/step
# Epoch 159/200
# 24/24 - 0s - loss: 0.0682 - accuracy: 0.9833 - 31ms/epoch - 1ms/step
# Epoch 160/200
# 24/24 - 0s - loss: 0.0733 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 161/200
# 24/24 - 0s - loss: 0.0795 - accuracy: 0.9750 - 32ms/epoch - 1ms/step
# Epoch 162/200
# 24/24 - 0s - loss: 0.0684 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 163/200
# 24/24 - 0s - loss: 0.0700 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 164/200
# 24/24 - 0s - loss: 0.0697 - accuracy: 0.9833 - 27ms/epoch - 1ms/step
# Epoch 165/200
# 24/24 - 0s - loss: 0.0690 - accuracy: 0.9750 - 34ms/epoch - 1ms/step
# Epoch 166/200
# 24/24 - 0s - loss: 0.0686 - accuracy: 0.9833 - 31ms/epoch - 1ms/step
# Epoch 167/200
# 24/24 - 0s - loss: 0.0752 - accuracy: 0.9750 - 32ms/epoch - 1ms/step
# Epoch 168/200
# 24/24 - 0s - loss: 0.0733 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 169/200
# 24/24 - 0s - loss: 0.0785 - accuracy: 0.9667 - 32ms/epoch - 1ms/step
# Epoch 170/200
# 24/24 - 0s - loss: 0.0681 - accuracy: 0.9833 - 29ms/epoch - 1ms/step
# Epoch 171/200
# 24/24 - 0s - loss: 0.0764 - accuracy: 0.9750 - 34ms/epoch - 1ms/step
# Epoch 172/200
# 24/24 - 0s - loss: 0.0738 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 173/200
# 24/24 - 0s - loss: 0.0724 - accuracy: 0.9750 - 31ms/epoch - 1ms/step
# Epoch 174/200
# 24/24 - 0s - loss: 0.0702 - accuracy: 0.9667 - 32ms/epoch - 1ms/step
# Epoch 175/200
# 24/24 - 0s - loss: 0.0824 - accuracy: 0.9667 - 32ms/epoch - 1ms/step
# Epoch 176/200
# 24/24 - 0s - loss: 0.0733 - accuracy: 0.9833 - 32ms/epoch - 1ms/step
# Epoch 177/200
# 24/24 - 0s - loss: 0.0772 - accuracy: 0.9667 - 30ms/epoch - 1ms/step
# Epoch 178/200
# 24/24 - 0s - loss: 0.0690 - accuracy: 0.9750 - 36ms/epoch - 2ms/step
# Epoch 179/200
# 24/24 - 0s - loss: 0.0683 - accuracy: 0.9667 - 28ms/epoch - 1ms/step
# Epoch 180/200
# 24/24 - 0s - loss: 0.0661 - accuracy: 0.9917 - 34ms/epoch - 1ms/step
# Epoch 181/200
# 24/24 - 0s - loss: 0.0681 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 182/200
# 24/24 - 0s - loss: 0.0701 - accuracy: 0.9833 - 30ms/epoch - 1ms/step
# Epoch 183/200
# 24/24 - 0s - loss: 0.0678 - accuracy: 0.9833 - 36ms/epoch - 1ms/step
# Epoch 184/200
# 24/24 - 0s - loss: 0.0681 - accuracy: 0.9833 - 30ms/epoch - 1ms/step
# Epoch 185/200
# 24/24 - 0s - loss: 0.0740 - accuracy: 0.9750 - 30ms/epoch - 1ms/step
# Epoch 186/200
# 24/24 - 0s - loss: 0.0764 - accuracy: 0.9667 - 30ms/epoch - 1ms/step
# Epoch 187/200
# 24/24 - 0s - loss: 0.0700 - accuracy: 0.9750 - 29ms/epoch - 1ms/step
# Epoch 188/200
# 24/24 - 0s - loss: 0.0684 - accuracy: 0.9750 - 29ms/epoch - 1ms/step
# Epoch 189/200
# 24/24 - 0s - loss: 0.0648 - accuracy: 0.9750 - 32ms/epoch - 1ms/step
# Epoch 190/200
# 24/24 - 0s - loss: 0.0664 - accuracy: 0.9833 - 33ms/epoch - 1ms/step
# Epoch 191/200
# 24/24 - 0s - loss: 0.0659 - accuracy: 0.9833 - 32ms/epoch - 1ms/step
# Epoch 192/200
# 24/24 - 0s - loss: 0.0658 - accuracy: 0.9750 - 29ms/epoch - 1ms/step
# Epoch 193/200
# 24/24 - 0s - loss: 0.0658 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 194/200
# 24/24 - 0s - loss: 0.0664 - accuracy: 0.9833 - 31ms/epoch - 1ms/step
# Epoch 195/200
# 24/24 - 0s - loss: 0.0698 - accuracy: 0.9750 - 30ms/epoch - 1ms/step
# Epoch 196/200
# 24/24 - 0s - loss: 0.0660 - accuracy: 0.9833 - 31ms/epoch - 1ms/step
# Epoch 197/200
# 24/24 - 0s - loss: 0.0673 - accuracy: 0.9833 - 31ms/epoch - 1ms/step
# Epoch 198/200
# 24/24 - 0s - loss: 0.0668 - accuracy: 0.9750 - 29ms/epoch - 1ms/step
# Epoch 199/200
# 24/24 - 0s - loss: 0.0689 - accuracy: 0.9750 - 29ms/epoch - 1ms/step
# Epoch 200/200
# 24/24 - 0s - loss: 0.0696 - accuracy: 0.9750 - 31ms/epoch - 1ms/step

# %%
# Test on unseen data
results = model.evaluate(test_x, test_y)
print('Final test set accuracy:',results[1])
# Out:
# 1/1 [==============================] - 0s 178ms/step - loss: 0.0377 - accuracy: 0.9667
# Final test set accuracy: 0.9666666388511658

# %%
x_test1 = [[4.6, 3.4, 1.4, 0.3]] # for new data testing
y_pred1 = model.predict(x_test1)
print("Predicted class is:",y_pred1)
# Out:
# 1/1 [==============================] - 0s 69ms/step
# Predicted class is: [[9.9970990e-01 2.9011187e-04 2.5023315e-11]]

# %%
y_classes = y_pred1.argmax(axis=-1)
print("The above data belongs to class ",y_classes[0])
# Out:
# The above data belongs to class  0
